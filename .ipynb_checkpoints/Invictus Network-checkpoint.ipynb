# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')



with open('Invictus.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')

text = soup.get_text()

words = word_tokenize(text)

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words and word.isalnum()]

filtered_text = ' '.join(filtered_words)

sid = SentimentIntensityAnalyzer()
sentiment_scores = sid.polarity_scores(filtered_text)

print(sentiment_scores)
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# {'neg': 0.138, 'neu': 0.68, 'pos': 0.181, 'compound': 1.0}

# %%
import matplotlib.pyplot as plt


scores = {
    'Negative': 0.138,
    'Neutral': 0.68,
    'Positive': 0.181,
    'Compound': 1.0
}


plt.figure(figsize=(12, 6))
plt.bar(scores.keys(), scores.values(), color=['pink', 'beige', 'orange', 'blue'])
plt.xlabel('Sentiment')
plt.ylabel('Score')
plt.title('Sentiment Analysis of Invictus')
plt.show()

# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

with open('Invictus.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')

text = soup.get_text()

chapters = text.split('Chapter')[1:]  
chapters = ['Chapter' + chapter for chapter in chapters]  


sid = SentimentIntensityAnalyzer()


def remove_stopwords(words):
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.lower() not in stop_words and word.isalnum()]
    return ' '.join(filtered_words)


chapter_sentiments = []

for chapter in chapters:
    words = word_tokenize(chapter)
    filtered_text = remove_stopwords(words)
    sentiment_scores = sid.polarity_scores(filtered_text)
    chapter_sentiments.append(sentiment_scores)


chapters_labels = [f'Chapter {i+1}' for i in range(len(chapter_sentiments))]


neg = [score['neg'] for score in chapter_sentiments]
neu = [score['neu'] for score in chapter_sentiments]
pos = [score['pos'] for score in chapter_sentiments]
compound = [score['compound'] for score in chapter_sentiments]


plt.figure(figsize=(14, 8))

plt.subplot(2, 1, 1)
plt.plot(chapters_labels, neg, label='Negative', color='green')
plt.plot(chapters_labels, neu, label='Neutral', color='beige')
plt.plot(chapters_labels, pos, label='Positive', color='pink')
plt.ylabel('Score')
plt.title('Sentiment Analysis by Chapter')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(chapters_labels, compound, label='Compound', color='blue')
plt.xlabel('Chapter')
plt.ylabel('Compound Score')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

with open('Invictus.html', 'r', encoding='utf-8') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')

text = soup.get_text()

chapters = text.split('Chapter')[1:]  # Skip the first element which is before the first chapter
chapters = ['Chapter' + chapter for chapter in chapters]  # Add 'Chapter' back to each split part

sid = SentimentIntensityAnalyzer()

def remove_stopwords(words):
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.lower() not in stop_words and word.isalnum()]
    return ' '.join(filtered_words)

chapter_sentiments = []

for chapter in chapters:
    words = word_tokenize(chapter)
    filtered_text = remove_stopwords(words)
    sentiment_scores = sid.polarity_scores(filtered_text)
    chapter_sentiments.append(sentiment_scores)

chapters_labels = [f'Ch {i+1}' for i in range(len(chapter_sentiments))]

neg = [score['neg'] for score in chapter_sentiments]
neu = [score['neu'] for score in chapter_sentiments]
pos = [score['pos'] for score in chapter_sentiments]
compound = [score['compound'] for score in chapter_sentiments]

plt.figure(figsize=(14, 10))

width = 0.2 
x = range(len(chapters_labels))

plt.bar(x, neg, width=width, label='Negative', color='darkgreen', align='center')
plt.bar([p + width for p in x], neu, width=width, label='Neutral', color='gray', align='center')
plt.bar([p + width*2 for p in x], pos, width=width, label='Positive', color='lightpink', align='center')

plt.xlabel('Chapter')
plt.ylabel('Score')
plt.title('Sentiment Analysis by Chapter')
plt.xticks([p + 1.5 * width for p in x], chapters_labels, rotation=90)
plt.legend()

plt.show()

plt.figure(figsize=(14, 6))
plt.bar(chapters_labels, compound, color='pink')
plt.xlabel('Chapter')
plt.ylabel('Compound Score')
plt.title('Compound Sentiment Score by Chapter')
plt
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
from bs4 import BeautifulSoup
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter
import re

def extract_text_from_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        soup = BeautifulSoup(file, 'html.parser')
        text = soup.get_text()
    return text

def find_characters(text):
    characters = ['Draco', 'Hermione', 'Harry', 'Lucius', 'Voldemort','Astoria', 'Snape', 'Madeye', 'Ron', 'Ginny', 'Padma', 'Blaise', 'Crookshanks', 'McCgonagal']
    character_mentions = {character: [] for character in characters}
    
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    for idx, sentence in enumerate(sentences):
        for character in characters:
            if character in sentence:
                character_mentions[character].append(idx)
    return character_mentions, sentences

def create_cooccurrence_matrix(character_mentions, sentences, window=5):
    cooccurrence = Counter()
    for character, indices in character_mentions.items():
        for idx in indices:
            start = max(0, idx - window)
            end = min(len(sentences), idx + window + 1)
            for other_character, other_indices in character_mentions.items():
                if other_character != character:
                    if any(i in range(start, end) for i in other_indices):
                        cooccurrence[(character, other_character)] += 1
    return cooccurrence

def plot_network(cooccurrence):
    G = nx.Graph()
    for (char1, char2), weight in cooccurrence.items():
        G.add_edge(char1, char2, weight=weight)

    pos = nx.spring_layout(G)
    plt.figure(figsize=(12, 12))

    nx.draw_networkx_nodes(G, pos, node_size=7000, node_color='skyblue')
    nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5)
    nx.draw_networkx_labels(G, pos, font_size=12, font_family='sans-serif')

    centrality = nx.degree_centrality(G)
    nx.draw_networkx
    
    centrality = nx.degree_centrality(G)
    nx.draw_networkx_nodes(G, pos, nodelist=centrality.keys(), node_size=[v * 10000 for v in centrality.values()])

    plt.title('Character Co-occurrence Network with Centrality')
    plt.show()

def main():
    file_path = 'Manacled.html' 
    text = extract_text_from_html(file_path)
    character_mentions, sentences = find_characters(text)
    cooccurrence = create_cooccurrence_matrix(character_mentions, sentences)
    plot_network(cooccurrence)

if __name__ == "__main__":
    main()
